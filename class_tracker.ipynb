# %%
import pytesseract
from PIL import Image, UnidentifiedImageError, ImageOps

def tracer_1():
    names = {
        "Aadhikesh": '1',
        "Adithya Ajay": '2',
        "Adithya Monish Kumar": '3',
        "Akshay K S": '4',
        "Amrith B": '5',
        "Adithya Nambiar P": '6',
        "Aravind": '8',
        "Aswath Siddharth": '9',
        "Bhairavabhotla Siva Sathwik": '10',
        "Bompalli Guru Sai Prasad Reddy": '11',
        "Burra Vijay Krishna": '12',
        "Bommadi Hemanth Kumar": '13',
        "Chagamreddy Shiv Sudeep": '14',
        "Darshan R": '15',
        "Dhanisetty Jnana Avinash": '16',
        "Doppalapudi Lakshmi Akshitha": '17',
        "Gayas Sheik": '18',
        "Gowreesh": '19',
        "Gauri Nandana Pai": '20',
        "Kavinesh Parthasarathi": '21',
        "Kshitij Varma Pinnamaraju": '22',
        "Kolla Akshara": '23',
        "Makam Sai Jeevan": '24',
        "Manish Sakamuri": '25',
        "Nagireddy Surya Tejeswar": '27',
        "Naveen Paventha": '28',
        "Nellore Sisir Reddy": '29',
        "Nitin": '30',
        "Nelluri Praveen": '31',
        "Nishanth E S": '32',
        "Ankith": '33',
        "Pasupuleti Meena Radhakrishna": '34',
        "Prajith": '35',
        "Praveen SB": '36',
        "Praveen P": '37',
        "RD Tarun": '38',
        "Rachit Anand": '39',
        "Rithanya K A": '40',
        "Rohith Abhinav Sai Komal Gullolla": '41',
        "S Ajeth": '42',
        "Sandheep G S": '44',
        "Sarvesha Nandha Kumar": '45',
        "Shantharam P": '46',
        "Shravanthi Satyanarayanan": '47',
        "Sujithkumar A": '48',
        "Saravana Priya": '49',
        "Subiksha Mangayarkarasi Vishwanathan": '50',
        "Vasudev Kishor": '51',
        "Vinaayak Kanagaraj": '52',
        "Yarra Tharun Kumar Reddy": '53',
        "Yerneni Vishnu Vardhan": '54',
        "Kanishka D": '55',
        "Kummithi Sneha Latha Reddy": '56',
        "Varun S": '57',
        "Kosuru Guru Sri Sai Siddhartha": '58',
        "Suthekshan Adeit Ayyankannu": '59',
        "Prem Patel": '60',
        "Kavin Karthik M": '61',
        "G Aakaash": '62',
        "Muppagowni Vamsidhar": '63',
        "Dasari Manoj Kumar": '64',
        "Thota Neha": '65',
        "Aswin L": '66',
        "Irene": '67',
        "Akshay": '68',
        "Jaikrishna S": '69'
    }

    entries = list(map(str, input("Enter the names or the roll numbers of validated students: ").split(',')))
    to_remove = []

    for a in entries:
        a = a.strip().lower()
        for x, y in names.items():
            if a in x.lower() or a == y:
                to_remove.append(x)
                break

    for x in to_remove:
        del names[x]

    print("Absentees are:")
    for words in names.keys():
        print(str(words))

def tracer_2():
    names = {
        "Aadhikesh": '1',
        "Adithya Ajay": '2',
        "Adithya Monish Kumar": '3',
        "Akshay K S": '4',
        "Amrith B": '5',
        "Adithya Nambiar P": '6',
        "Aravind": '8',
        "Aswath Siddharth": '9',
        "Bhairavabhotla Siva Sathwik": '10',
        "Bompalli Guru Sai Prasad Reddy": '11',
        "Burra Vijay Krishna": '12',
        "Bommadi Hemanth Kumar": '13',
        "Chagamreddy Shiv Sudeep": '14',
        "Darshan R": '15',
        "Dhanisetty Jnana Avinash": '16',
        "Doppalapudi Lakshmi Akshitha": '17',
        "Gayas Sheik": '18',
        "Gowreesh": '19',
        "Gauri Nandana Pai": '20',
        "Kavinesh Parthasarathi": '21',
        "Kshitij Varma Pinnamaraju": '22',
        "Kolla Akshara": '23',
        "Makam Sai Jeevan": '24',
        "Manish Sakamuri": '25',
        "Nagireddy Surya Tejeswar": '27',
        "Naveen Paventha": '28',
        "Nellore Sisir Reddy": '29',
        "Nitin": '30',
        "Nelluri Praveen": '31',
        "Nishanth E S": '32',
        "Ankith": '33',
        "Pasupuleti Meena Radhakrishna": '34',
        "Prajith": '35',
        "Praveen SB": '36',
        "Praveen P": '37',
        "RD Tarun": '38',
        "Rachit Anand": '39',
        "Rithanya K A": '40',
        "Rohith Abhinav Sai Komal Gullolla": '41',
        "S Ajeth": '42',
        "Sandheep G S": '44',
        "Sarvesha Nandha Kumar": '45',
        "Shantharam P": '46',
        "Shravanthi Satyanarayanan": '47',
        "Sujithkumar A": '48',
        "Saravana Priya": '49',
        "Subiksha Mangayarkarasi Vishwanathan": '50',
        "Vasudev Kishor": '51',
        "Vinaayak Kanagaraj": '52',
        "Yarra Tharun Kumar Reddy": '53',
        "Yerneni Vishnu Vardhan": '54',
        "Kanishka D": '55',
        "Kummithi Sneha Latha Reddy": '56',
        "Varun S": '57',
        "Kosuru Guru Sri Sai Siddhartha": '58',
        "Suthekshan Adeit Ayyankannu": '59',
        "Prem Patel": '60',
        "Kavin Karthik M": '61',
        "G Aakaash": '62',
        "Muppagowni Vamsidhar": '63',
        "Dasari Manoj Kumar": '64',
        "Thota Neha": '65',
        "Aswin L": '66',
        "Irene": '67',
        "Akshay": '68',
        "Jaikrishna S": '69'
    }

    try:
        # Open the image file
        image1 = Image.open('image5.jpeg')

        # Convert image to RGB if it is not in RGB mode
        if image1.mode != 'RGB':
            image1 = image1.convert('RGB')

        # Perform OCR using PyTesseract
        text = pytesseract.image_to_string(image1)
        entries = text.split('\n')

        to_remove = []
        for a in entries:
            a = a.strip()
            if a == '':
                continue
            if a == "You":
                to_remove.append("Vinaayak Kanagaraj")
            else:
                for x in names.keys():
                    if a.strip().lower() in x.lower():
                        to_remove.append(x)
                        break

        for x in to_remove:
            del names[x]

        print("Students who have not responded:")
        for x in names.keys():
            print(x)

    except UnidentifiedImageError:
        print("Error: Cannot identify the image file. Please check the file format.")
    except pytesseract.TesseractError as e:
        print(f"TesseractError: {e.message}")
    except Exception as e:
        print(f"An error occurred: {e}")

decision = int(input("Enter 1 for manual input or 2 for OCR processing: "))
if decision == 1:
    tracer_1()
elif decision == 2:
    tracer_2()
# Out:
# Absentees are:
# Adithya Monish Kumar
# Akshay K S
# Amrith B
# Adithya Nambiar P
# Aravind
# Aswath Siddharth
# Bhairavabhotla Siva Sathwik
# Bompalli Guru Sai Prasad Reddy
# Burra Vijay Krishna
# Bommadi Hemanth Kumar
# Chagamreddy Shiv Sudeep
# Darshan R
# Dhanisetty Jnana Avinash
# Doppalapudi Lakshmi Akshitha
# Gayas Sheik
# Gowreesh
# Gauri Nandana Pai
# Kavinesh Parthasarathi
# Kshitij Varma Pinnamaraju
# Kolla Akshara
# Makam Sai Jeevan
# Manish Sakamuri
# Nagireddy Surya Tejeswar
# Naveen Paventha
# Nellore Sisir Reddy
# Nitin
# Nelluri Praveen
# Nishanth E S
# Ankith
# Pasupuleti Meena Radhakrishna
# Prajith
# Praveen SB
# Praveen P
# RD Tarun
# Rachit Anand
# Rithanya K A
# Rohith Abhinav Sai Komal Gullolla
# S Ajeth
# Sandheep G S
# Sarvesha Nandha Kumar
# Shantharam P
# Shravanthi Satyanarayanan
# Sujithkumar A
# Saravana Priya
# Subiksha Mangayarkarasi Vishwanathan
# Vasudev Kishor
# Vinaayak Kanagaraj
# Yarra Tharun Kumar Reddy
# Yerneni Vishnu Vardhan
# Kanishka D
# ...
